# %% [markdown]
# <h1>Import Library</h1>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
print("LOADED OPENCV")
# from cvlib.object_detection import draw_bbox

# %% [markdown]
# <h1>Load Image</h1>

# %%
#load image
image = cv.imread('assets/road_1.jpg')
plate = cv.imread('Labeled_Plates')
img = image[:,:,::-1]
plt.imshow(img)

# %% [markdown]
# <h1>PreProcessing Image</h1>

# %%
#Gray scale image
imgray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
# img1 = imgray[:,:,::-1]
figure(1)
plt.imshow(imgray, cmap='gray')

#hsv 
hsv = cv.cvtColor(image, cv.COLOR_BGR2HSV)
# img2 = hsv[:,:,::-1]
plt.imshow(hsv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1a8cbc77e53a> in <module>
#       2 imgray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
#       3 # img1 = imgray[:,:,::-1]
# ----> 4 figure(1)
#       5 plt.imshow(imgray, cmap='gray')
#       6
#
# NameError: name 'figure' is not defined

# %%
#threshold - yellow
lower_yellow = np.array([20,100,100])
upper_yellow = np.array([30,255,255])

#mask for yellow license plate
mask = cv.inRange(hsv,lower_yellow,upper_yellow)
cv.imshow("mask",mask)
cv.waitKey(0)
cv.destroyAllWindows()

#contour
contours = cv.findContours(mask,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
print(contours)
cv.drawContours(image,contours, -1,(0,255,0), 3)
# Out:
# ([array([[[257, 715]],
#
#        [[256, 716]],
#
#        [[255, 716]],
#
#        [[254, 717]],
#
#        [[253, 717]],
#
#        [[252, 718]],
#
#        [[252, 719]],
#
#        [[253, 719]]], dtype=int32), array([[[242, 714]]], dtype=int32), array([[[219, 714]],
#
#        [[218, 715]],
#
#        [[217, 715]],
#
#        [[215, 717]],
#
#        [[216, 717]]], dtype=int32), array([[[261, 712]]], dtype=int32), array([[[238, 710]],
#
#        [[237, 711]],
#
#        [[233, 711]],
#
#        [[228, 716]],
#
#        [[227, 716]],
#
#        [[226, 717]],
#
#        [[224, 717]],
#
#        [[224, 719]],
#
#        [[229, 719]],
#
#        [[230, 718]],
#
#        [[230, 717]],
#
#        [[231, 716]],
#
#        [[232, 716]],
#
#        [[231, 715]],
#
#        [[231, 714]],
#
#        [[232, 713]],
#
#        [[233, 714]],
#
#        [[234, 714]],
#
#        [[236, 712]],
#
#        [[237, 712]],
#
#        [[239, 710]]], dtype=int32), array([[[233, 712]],
#
#        [[234, 711]],
#
#        [[235, 712]],
#
#        [[234, 713]]], dtype=int32), array([[[272, 709]],
#
#        [[272, 710]],
#
#        [[271, 711]],
#
#        [[270, 711]],
#
#        [[267, 714]],
#
#        [[266, 714]],
#
#        [[264, 716]],
#
#        [[263, 716]],
#
#        [[262, 717]],
#
#        [[260, 717]],
#
#        [[260, 719]],
#
#        [[267, 719]],
#
#        [[267, 718]],
#
#        [[268, 717]],
#
#        [[268, 716]],
#
#        [[269, 715]],
#
#        [[272, 715]],
#
#        [[273, 714]],
#
#        [[274, 714]],
#
#        [[276, 712]],
#
#        [[276, 710]],
#
#        [[275, 710]],
#
#        [[274, 709]]], dtype=int32), array([[[249, 709]],
#
#        [[248, 710]],
#
#        [[247, 710]],
#
#        [[244, 713]],
#
#        [[245, 713]],
#
#        [[246, 712]],
#
#        [[247, 712]],
#
#        [[250, 709]]], dtype=int32), array([[[246, 711]],
#
#        [[247, 710]],
#
#        [[248, 711]],
#
#        [[247, 712]]], dtype=int32), array([[[292, 707]]], dtype=int32), array([[[292, 704]],
#
#        [[289, 707]],
#
#        [[288, 707]],
#
#        [[287, 708]],
#
#        [[286, 708]],
#
#        [[286, 710]],
#
#        [[284, 712]],
#
#        [[283, 712]],
#
#        [[283, 713]],
#
#        [[282, 714]],
#
#        [[280, 714]],
#
#        [[280, 715]],
#
#        [[279, 716]],
#
#        [[278, 716]],
#
#        [[278, 717]],
#
#        [[276, 719]],
#
#        [[275, 719]],
#
#        [[279, 719]],
#
#        [[279, 718]],
#
#        [[282, 715]],
#
#        [[282, 714]],
#
#        [[284, 712]],
#
#        [[285, 712]],
#
#        [[286, 711]],
#
#        [[286, 709]],
#
#        [[287, 708]],
#
#        [[288, 709]],
#
#        [[289, 708]],
#
#        [[290, 708]],
#
#        [[289, 707]],
#
#        [[291, 705]],
#
#        [[292, 705]]], dtype=int32), array([[[285, 701]],
#
#        [[284, 702]],
#
#        [[283, 702]],
#
#        [[283, 703]],
#
#        [[282, 704]],
#
#        [[282, 705]],
#
#        [[283, 705]],
#
#        [[284, 706]],
#
#        [[285, 705]],
#
#        [[286, 705]],
#
#        [[287, 704]],
#
#        [[287, 702]],
#
#        [[286, 701]]], dtype=int32), array([[[270, 701]],
#
#        [[270, 702]],
#
#        [[269, 703]],
#
#        [[270, 704]],
#
#        [[269, 705]],
#
#        [[270, 705]],
#
#        [[271, 704]],
#
#        [[271, 703]],
#
#        [[270, 702]]], dtype=int32), array([[[275, 700]],
#
#        [[274, 701]]], dtype=int32), array([[[261, 700]],
#
#        [[258, 703]]], dtype=int32), array([[[249, 700]],
#
#        [[248, 701]],
#
#        [[247, 701]],
#
#        [[246, 702]],
#
#        [[247, 702]],
#
#        [[248, 703]],
#
#        [[249, 702]],
#
#        [[250, 702]],
#
#        [[250, 700]]], dtype=int32), array([[[279, 697]]], dtype=int32), array([[[296, 696]]], dtype=int32), array([[[288, 690]]], dtype=int32), array([[[290, 688]]], dtype=int32), array([[[266, 688]],
#
#        [[265, 689]],
#
#        [[263, 689]],
#
#        [[263, 690]],
#
#        [[265, 690]],
#
#        [[266, 689]]], dtype=int32), array([[[315, 685]],
#
#        [[314, 686]],
#
#        [[313, 686]],
#
#        [[310, 689]],
#
#        [[309, 689]],
#
#        [[308, 690]],
#
#        [[308, 691]],
#
#        [[307, 692]],
#
#        [[306, 692]],
#
#        [[306, 693]],
#
#        [[305, 694]],
#
#        [[304, 694]],
#
#        [[301, 697]],
#
#        [[300, 697]],
#
#        [[295, 702]],
#
#        [[294, 702]],
#
#        [[294, 703]],
#
#        [[295, 702]],
#
#        [[296, 703]],
#
#        [[301, 698]],
#
#        [[302, 698]],
#
#        [[302, 697]],
#
#        [[303, 696]],
#
#        [[303, 695]],
#
#        [[304, 694]],
#
#        [[306, 694]],
#
#        [[311, 689]],
#
#        [[311, 688]],
#
#        [[312, 687]],
#
#        [[315, 687]]], dtype=int32), array([[[295, 702]],
#
#        [[296, 701]],
#
#        [[297, 702]],
#
#        [[296, 703]]], dtype=int32), array([[[308, 690]],
#
#        [[309, 689]],
#
#        [[310, 690]],
#
#        [[309, 691]]], dtype=int32), array([[[318, 683]],
#
#        [[317, 684]],
#
#        [[318, 683]],
#
#        [[319, 683]]], dtype=int32), array([[[320, 680]],
#
#        [[319, 681]]], dtype=int32), array([[[324, 677]],
#
#        [[322, 679]],
#
#        [[323, 679]],
#
#        [[323, 678]],
#
#        [[324, 677]],
#
#        [[325, 678]]], dtype=int32), array([[[305, 676]]], dtype=int32), array([[[272, 676]]], dtype=int32), array([[[327, 675]]], dtype=int32), array([[[307, 674]]], dtype=int32), array([[[299, 672]],
#
#        [[297, 674]],
#
#        [[296, 674]],
#
#        [[293, 677]],
#
#        [[292, 677]],
#
#        [[289, 680]],
#
#        [[286, 680]],
#
#        [[281, 685]],
#
#        [[280, 685]],
#
#        [[277, 688]],
#
#        [[276, 688]],
#
#        [[272, 692]],
#
#        [[277, 692]],
#
#        [[278, 691]],
#
#        [[279, 691]],
#
#        [[281, 689]],
#
#        [[281, 688]],
#
#        [[282, 687]],
#
#        [[283, 688]],
#
#        [[282, 687]],
#
#        [[282, 686]],
#
#        [[283, 685]],
#
#        [[285, 685]],
#
#        [[290, 680]],
#
#        [[291, 680]],
#
#        [[293, 678]],
#
#        [[294, 679]],
#
#        [[295, 679]],
#
#        [[296, 680]],
#
#        [[295, 681]],
#
#        [[295, 682]],
#
#        [[294, 683]],
#
#        [[293, 683]],
#
#        [[292, 684]],
#
#        [[294, 684]],
#
#        [[296, 682]],
#
#        [[297, 682]],
#
#        [[299, 680]],
#
#        [[299, 679]],
#
#        [[298, 680]],
#
#        [[296, 680]],
#
#        [[295, 679]],
#
#        [[295, 678]],
#
#        [[297, 676]],
#
#        [[297, 675]],
#
#        [[298, 674]],
#
#        [[299, 674]]], dtype=int32), array([[[274, 691]],
#
#        [[275, 690]],
#
#        [[276, 691]],
#
#        [[275, 692]]], dtype=int32), array([[[277, 688]],
#
#        [[278, 687]],
#
#        [[279, 687]],
#
#        [[280, 688]],
#
#        [[279, 689]],
#
#        [[278, 689]]], dtype=int32), array([[[311, 663]],
#
#        [[310, 664]],
#
#        [[309, 664]],
#
#        [[307, 666]],
#
#        [[306, 666]],
#
#        [[306, 667]],
#
#        [[305, 668]],
#
#        [[304, 668]],
#
#        [[304, 670]],
#
#        [[305, 669]],
#
#        [[307, 669]],
#
#        [[308, 668]],
#
#        [[309, 668]],
#
#        [[310, 669]],
#
#        [[310, 670]],
#
#        [[309, 671]],
#
#        [[310, 672]],
#
#        [[311, 672]],
#
#        [[311, 670]],
#
#        [[312, 669]],
#
#        [[313, 669]],
#
#        [[314, 668]],
#
#        [[315, 668]],
#
#        [[315, 666]],
#
#        [[313, 664]],
#
#        [[313, 663]]], dtype=int32), array([[[307, 667]],
#
#        [[308, 666]],
#
#        [[309, 667]],
#
#        [[308, 668]]], dtype=int32), array([[[310, 664]],
#
#        [[311, 663]],
#
#        [[312, 664]],
#
#        [[311, 665]]], dtype=int32), array([[[316, 660]],
#
#        [[316, 661]]], dtype=int32), array([[[328, 656]]], dtype=int32), array([[[335, 645]],
#
#        [[333, 647]],
#
#        [[332, 647]],
#
#        [[329, 650]],
#
#        [[328, 650]],
#
#        [[326, 652]],
#
#        [[326, 653]],
#
#        [[327, 653]],
#
#        [[328, 652]],
#
#        [[330, 654]],
#
#        [[330, 655]],
#
#        [[332, 653]],
#
#        [[333, 653]],
#
#        [[334, 652]],
#
#        [[334, 650]],
#
#        [[333, 649]],
#
#        [[333, 648]],
#
#        [[335, 646]]], dtype=int32), array([[[330, 651]],
#
#        [[331, 650]],
#
#        [[332, 651]],
#
#        [[332, 652]],
#
#        [[331, 653]],
#
#        [[330, 652]]], dtype=int32), array([[[327, 651]],
#
#        [[328, 650]],
#
#        [[329, 651]],
#
#        [[328, 652]]], dtype=int32), array([[[343, 643]],
#
#        [[344, 644]],
#
#        [[344, 645]],
#
#        [[345, 644]],
#
#        [[345, 643]]], dtype=int32), array([[[341, 640]],
#
#        [[339, 642]],
#
#        [[340, 642]],
#
#        [[341, 641]]], dtype=int32), array([[[358, 627]],
#
#        [[356, 629]],
#
#        [[355, 629]],
#
#        [[353, 631]],
#
#        [[352, 631]],
#
#        [[351, 632]],
#
#        [[350, 632]],
#
#        [[350, 633]],
#
#        [[348, 635]],
#
#        [[347, 635]],
#
#        [[343, 639]],
#
#        [[343, 640]],
#
#        [[346, 637]],
#
#        [[348, 637]],
#
#        [[350, 635]],
#
#        [[351, 635]],
#
#        [[352, 634]],
#
#        [[353, 635]],
#
#        [[353, 636]],
#
#        [[354, 636]],
#
#        [[355, 635]],
#
#        [[355, 634]],
#
#        [[357, 632]],
#
#        [[359, 632]],
#
#        [[358, 631]],
#
#        [[357, 631]],
#
#        [[356, 630]],
#
#        [[359, 627]]], dtype=int32), array([[[346, 636]],
#
#        [[347, 635]],
#
#        [[348, 635]],
#
#        [[349, 636]],
#
#        [[348, 637]],
#
#        [[347, 637]]], dtype=int32), array([[[352, 634]],
#
#        [[353, 633]],
#
#        [[354, 634]],
#
#        [[353, 635]]], dtype=int32), array([[[355, 631]],
#
#        [[356, 630]],
#
#        [[357, 631]],
#
#        [[356, 632]]], dtype=int32), array([[[364, 622]],
#
#        [[363, 623]],
#
#        [[364, 623]],
#
#        [[365, 622]],
#
#        [[366, 622]]], dtype=int32), array([[[839, 570]],
#
#        [[839, 571]],
#
#        [[840, 571]],
#
#        [[840, 570]]], dtype=int32), array([[[876, 567]],
#
#        [[875, 568]],
#
#        [[869, 568]],
#
#        [[868, 569]],
#
#        [[867, 569]],
#
#        [[866, 570]],
#
#        [[865, 570]],
#
#        [[864, 569]],
#
#        [[863, 570]],
#
#        [[862, 570]],
#
#        [[861, 569]],
#
#        [[860, 569]],
#
#        [[859, 570]],
#
#        [[858, 569]],
#
#        [[855, 569]],
#
#        [[854, 568]],
#
#        [[851, 568]],
#
#        [[850, 569]],
#
#        [[847, 569]],
#
#        [[846, 570]],
#
#        [[847, 570]],
#
#        [[848, 571]],
#
#        [[847, 572]],
#
#        [[845, 572]],
#
#        [[844, 573]],
#
#        [[844, 574]],
#
#        [[845, 575]],
#
#        [[844, 576]],
#
#        [[843, 576]],
#
#        [[842, 575]],
#
#        [[842, 571]],
#
#        [[843, 570]],
#
#        [[844, 570]],
#
#        [[842, 570]],
#
#        [[842, 574]],
#
#        [[841, 575]],
#
#        [[840, 574]],
#
#        [[840, 573]],
#
#        [[840, 574]],
#
#        [[838, 576]],
#
#        [[837, 575]],
#
#        [[837, 572]],
#
#        [[836, 571]],
#
#        [[831, 571]],
#
#        [[830, 570]],
#
#        [[829, 571]],
#
#        [[816, 571]],
#
#        [[816, 575]],
#
#        [[817, 576]],
#
#        [[817, 578]],
#
#        [[816, 579]],
#
#        [[816, 581]],
#
#        [[816, 580]],
#
#        [[817, 579]],
#
#        [[821, 579]],
#
#        [[823, 581]],
#
#        [[823, 583]],
#
#        [[831, 583]],
#
#        [[831, 582]],
#
#        [[832, 581]],
#
#        [[836, 581]],
#
#        [[837, 580]],
#
#        [[838, 580]],
#
#        [[839, 581]],
#
#        [[840, 581]],
#
#        [[841, 580]],
#
#        [[842, 581]],
#
#        [[847, 581]],
#
#        [[848, 582]],
#
#        [[852, 582]],
#
#        [[853, 581]],
#
#        [[855, 581]],
#
#        [[856, 580]],
#
#        [[857, 580]],
#
#        [[858, 581]],
#
#        [[859, 580]],
#
#        [[865, 580]],
#
#        [[866, 581]],
#
#        [[868, 581]],
#
#        [[869, 580]],
#
#        [[870, 581]],
#
#        [[873, 581]],
#
#        [[874, 582]],
#
#        [[876, 582]],
#
#        [[877, 581]],
#
#        [[879, 581]],
#
#        [[879, 573]],
#
#        [[878, 572]],
#
#        [[878, 570]],
#
#        [[879, 569]],
#
#        [[879, 567]],
#
#        [[878, 567]],
#
#        [[878, 570]],
#
#        [[877, 571]],
#
#        [[876, 570]]], dtype=int32), array([[[869, 579]],
#
#        [[870, 578]],
#
#        [[871, 578]],
#
#        [[872, 579]],
#
#        [[871, 580]],
#
#        [[870, 580]]], dtype=int32), array([[[860, 579]],
#
#        [[861, 578]],
#
#        [[864, 578]],
#
#        [[865, 579]],
#
#        [[864, 580]],
#
#        [[861, 580]]], dtype=int32), array([[[842, 579]],
#
#        [[843, 578]],
#
#        [[844, 578]],
#
#        [[845, 579]],
#
#        [[845, 580]],
#
#        [[844, 581]]], dtype=int32), array([[[831, 579]],
#
#        [[832, 578]],
#
#        [[834, 580]],
#
#        [[833, 581]],
#
#        [[832, 581]],
#
#        [[831, 580]]], dtype=int32), array([[[871, 578]],
#
#        [[872, 577]],
#
#        [[873, 578]],
#
#        [[872, 579]]], dtype=int32), array([[[864, 578]],
#
#        [[865, 577]],
#
#        [[866, 578]],
#
#        [[865, 579]]], dtype=int32), array([[[856, 578]],
#
#        [[857, 577]],
#
#        [[858, 578]],
#
#        [[858, 579]],
#
#        [[857, 580]],
#
#        [[854, 580]],
#
#        [[853, 579]],
#
#        [[854, 578]]], dtype=int32), array([[[846, 578]],
#
#        [[847, 577]],
#
#        [[848, 578]],
#
#        [[848, 579]],
#
#        [[847, 580]],
#
#        [[846, 579]]], dtype=int32), array([[[839, 578]],
#
#        [[840, 577]],
#
#        [[841, 578]],
#
#        [[840, 579]]], dtype=int32), array([[[835, 578]],
#
#        [[836, 577]],
#
#        [[837, 578]],
#
#        [[837, 579]],
#
#        [[836, 580]],
#
#        [[835, 579]]], dtype=int32), array([[[844, 577]],
#
#        [[845, 576]],
#
#        [[846, 577]],
#
#        [[845, 578]]], dtype=int32), array([[[835, 576]],
#
#        [[836, 575]],
#
#        [[837, 576]],
#
#        [[836, 577]]], dtype=int32), array([[[823, 576]],
#
#        [[824, 575]],
#
#        [[827, 575]],
#
#        [[828, 576]],
#
#        [[827, 577]],
#
#        [[825, 577]],
#
#        [[825, 579]],
#
#        [[824, 580]],
#
#        [[823, 579]]], dtype=int32), array([[[862, 575]],
#
#        [[863, 574]],
#
#        [[864, 574]],
#
#        [[865, 575]],
#
#        [[864, 576]],
#
#        [[863, 576]]], dtype=int32), array([[[845, 575]],
#
#        [[846, 574]],
#
#        [[847, 574]],
#
#        [[848, 575]],
#
#        [[847, 576]],
#
#        [[846, 576]]], dtype=int32), array([[[831, 575]],
#
#        [[832, 574]],
#
#        [[833, 575]],
#
#        [[833, 576]],
#
#        [[832, 577]],
#
#        [[831, 576]]], dtype=int32), array([[[873, 573]],
#
#        [[874, 574]],
#
#        [[874, 575]],
#
#        [[873, 576]],
#
#        [[872, 576]],
#
#        [[871, 575]]], dtype=int32), array([[[833, 574]],
#
#        [[834, 573]],
#
#        [[835, 574]],
#
#        [[834, 575]]], dtype=int32), array([[[829, 574]],
#
#        [[830, 573]],
#
#        [[831, 574]],
#
#        [[830, 575]]], dtype=int32), array([[[869, 573]],
#
#        [[870, 572]],
#
#        [[871, 573]],
#
#        [[870, 574]]], dtype=int32), array([[[865, 573]],
#
#        [[866, 572]],
#
#        [[867, 573]],
#
#        [[867, 574]],
#
#        [[866, 575]],
#
#        [[865, 574]]], dtype=int32), array([[[863, 573]],
#
#        [[864, 572]],
#
#        [[865, 573]],
#
#        [[864, 574]]], dtype=int32), array([[[860, 573]],
#
#        [[861, 572]],
#
#        [[862, 573]],
#
#        [[862, 575]],
#
#        [[861, 576]],
#
#        [[860, 575]]], dtype=int32), array([[[830, 572]],
#
#        [[831, 571]],
#
#        [[836, 571]],
#
#        [[837, 572]],
#
#        [[837, 573]],
#
#        [[836, 574]],
#
#        [[835, 573]],
#
#        [[833, 573]],
#
#        [[832, 574]]], dtype=int32), array([[[823, 572]],
#
#        [[824, 571]],
#
#        [[828, 571]],
#
#        [[829, 572]],
#
#        [[828, 573]],
#
#        [[825, 573]],
#
#        [[825, 574]],
#
#        [[824, 575]],
#
#        [[823, 574]]], dtype=int32), array([[[871, 571]],
#
#        [[872, 570]],
#
#        [[873, 571]],
#
#        [[873, 572]],
#
#        [[872, 573]],
#
#        [[871, 572]]], dtype=int32), array([[[862, 571]],
#
#        [[863, 570]],
#
#        [[864, 570]],
#
#        [[865, 571]],
#
#        [[864, 572]],
#
#        [[863, 572]]], dtype=int32), array([[[860, 571]],
#
#        [[861, 570]],
#
#        [[862, 571]],
#
#        [[861, 572]]], dtype=int32), array([[[856, 571]],
#
#        [[857, 570]],
#
#        [[858, 571]],
#
#        [[858, 575]],
#
#        [[857, 576]],
#
#        [[856, 575]]], dtype=int32), array([[[867, 570]],
#
#        [[868, 569]],
#
#        [[869, 570]],
#
#        [[869, 575]],
#
#        [[868, 576]],
#
#        [[867, 575]]], dtype=int32), array([[[867, 565]]], dtype=int32), array([[[499, 504]],
#
#        [[497, 506]],
#
#        [[496, 506]],
#
#        [[495, 505]],
#
#        [[493, 505]],
#
#        [[491, 507]],
#
#        [[492, 508]],
#
#        [[492, 510]],
#
#        [[493, 511]],
#
#        [[493, 519]],
#
#        [[495, 521]],
#
#        [[496, 521]],
#
#        [[497, 522]],
#
#        [[498, 522]],
#
#        [[499, 523]],
#
#        [[500, 523]],
#
#        [[501, 522]],
#
#        [[502, 522]],
#
#        [[503, 521]],
#
#        [[503, 518]],
#
#        [[504, 517]],
#
#        [[503, 516]],
#
#        [[503, 512]],
#
#        [[504, 511]],
#
#        [[504, 509]],
#
#        [[503, 508]],
#
#        [[503, 507]],
#
#        [[501, 505]],
#
#        [[500, 505]]], dtype=int32), array([[[496, 513]],
#
#        [[497, 512]],
#
#        [[498, 513]],
#
#        [[497, 514]]], dtype=int32), array([[[719, 480]]], dtype=int32), array([[[708, 477]],
#
#        [[708, 478]],
#
#        [[707, 479]],
#
#        [[708, 479]],
#
#        [[709, 480]],
#
#        [[709, 482]],
#
#        [[708, 483]],
#
#        [[707, 483]],
#
#        [[715, 483]],
#
#        [[713, 481]],
#
#        [[716, 478]],
#
#        [[715, 477]]], dtype=int32)], array([[[ 1, -1, -1, -1],
#         [ 2,  0, -1, -1],
#         [ 3,  1, -1, -1],
#         [ 4,  2, -1, -1],
#         [ 6,  3,  5, -1],
#         [-1, -1, -1,  4],
#         [ 7,  4, -1, -1],
#         [ 9,  6,  8, -1],
#         [-1, -1, -1,  7],
#         [10,  7, -1, -1],
#         [11,  9, -1, -1],
#         [12, 10, -1, -1],
#         [13, 11, -1, -1],
#         [14, 12, -1, -1],
#         [15, 13, -1, -1],
#         [16, 14, -1, -1],
#         [17, 15, -1, -1],
#         [18, 16, -1, -1],
#         [19, 17, -1, -1],
#         [20, 18, -1, -1],
#         [21, 19, -1, -1],
#         [24, 20, 22, -1],
#         [23, -1, -1, 21],
#         [-1, 22, -1, 21],
#         [25, 21, -1, -1],
#         [26, 24, -1, -1],
#         [27, 25, -1, -1],
#         [28, 26, -1, -1],
#         [29, 27, -1, -1],
#         [30, 28, -1, -1],
#         [31, 29, -1, -1],
#         [34, 30, 32, -1],
#         [33, -1, -1, 31],
#         [-1, 32, -1, 31],
#         [37, 31, 35, -1],
#         [36, -1, -1, 34],
#         [-1, 35, -1, 34],
#         [38, 34, -1, -1],
#         [39, 37, -1, -1],
#         [42, 38, 40, -1],
#         [41, -1, -1, 39],
#         [-1, 40, -1, 39],
#         [43, 39, -1, -1],
#         [44, 42, -1, -1],
#         [48, 43, 45, -1],
#         [46, -1, -1, 44],
#         [47, 45, -1, 44],
#         [-1, 46, -1, 44],
#         [49, 44, -1, -1],
#         [50, 48, -1, -1],
#         [81, 49, 51, -1],
#         [52, -1, -1, 50],
#         [53, 51, -1, 50],
#         [54, 52, -1, 50],
#         [55, 53, -1, 50],
#         [56, 54, -1, 50],
#         [57, 55, -1, 50],
#         [58, 56, -1, 50],
#         [59, 57, -1, 50],
#         [60, 58, -1, 50],
#         [61, 59, -1, 50],
#         [62, 60, -1, 50],
#         [63, 61, -1, 50],
#         [64, 62, -1, 50],
#         [65, 63, -1, 50],
#         [66, 64, -1, 50],
#         [67, 65, -1, 50],
#         [68, 66, -1, 50],
#         [69, 67, -1, 50],
#         [70, 68, -1, 50],
#         [71, 69, -1, 50],
#         [72, 70, -1, 50],
#         [73, 71, -1, 50],
#         [74, 72, -1, 50],
#         [75, 73, -1, 50],
#         [76, 74, -1, 50],
#         [77, 75, -1, 50],
#         [78, 76, -1, 50],
#         [79, 77, -1, 50],
#         [80, 78, -1, 50],
#         [-1, 79, -1, 50],
#         [82, 50, -1, -1],
#         [84, 81, 83, -1],
#         [-1, -1, -1, 82],
#         [85, 82, -1, -1],
#         [-1, 84, -1, -1]]], dtype=int32))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-a628dcfc13df> in <module>
#      12 contours = cv.findContours(mask,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
#      13 print(contours)
# ---> 14 cv.drawContours(image,contours, -1,(0,255,0), 3)
#
# TypeError: contours is not a numpy array, neither a scalar
